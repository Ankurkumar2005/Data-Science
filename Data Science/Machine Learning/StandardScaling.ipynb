# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

# %%
data = {
    'age':[25,30,40,45],
    'height':[165,149,175,167],
    'weight':[60,70,76,78]
              }
df= pd.DataFrame(data)
df
# Out:
#    age  height  weight
# 0   25     165      60
# 1   30     149      70
# 2   40     175      76
# 3   45     167      78

# %%
scalar = StandardScaler()
scaled_df = scalar.fit_transform(df)
scaled_df
# Out:
# array([[-1.26491106,  0.10599979, -1.57142857],
#        [-0.63245553, -1.58999682, -0.14285714],
#        [ 0.63245553,  1.16599767,  0.71428571],
#        [ 1.26491106,  0.31799936,  1.        ]])

# %%
# convert this data into a pandas dataframe
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df
# Out:
#         age    height    weight
# 0 -1.264911  0.106000 -1.571429
# 1 -0.632456 -1.589997 -0.142857
# 2  0.632456  1.165998  0.714286
# 3  1.264911  0.317999  1.000000

# %% [markdown]
# # Min-Max Scalrr

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data = {
    'age':[25,30,40,45],
    'height':[165,149,175,167],
    'weight':[60,70,76,78]
              }
df1= pd.DataFrame(data)
df1
# Out:
#    age  height  weight
# 0   25     165      60
# 1   30     149      70
# 2   40     175      76
# 3   45     167      78

# %%
scalar1 = MinMaxScaler()
scaled_df = scalar1.fit_transform(df1)
scaled_df
# Out:
# array([[0.        , 0.61538462, 0.        ],
#        [0.25      , 0.        , 0.55555556],
#        [0.75      , 1.        , 0.88888889],
#        [1.        , 0.69230769, 1.        ]])

# %%
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df
# Out:
#     age    height    weight
# 0  0.00  0.615385  0.000000
# 1  0.25  0.000000  0.555556
# 2  0.75  1.000000  0.888889
# 3  1.00  0.692308  1.000000

# %% [markdown]
# # Max Abslout Error

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
scaler = MaxAbsScaler()
scaled_df = scalar1.fit_transform(df1)
scaled_df
# Out:
# array([[0.        , 0.61538462, 0.        ],
#        [0.25      , 0.        , 0.55555556],
#        [0.75      , 1.        , 0.88888889],
#        [1.        , 0.69230769, 1.        ]])

# %%
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df
# Out:
#     age    height    weight
# 0  0.00  0.615385  0.000000
# 1  0.25  0.000000  0.555556
# 2  0.75  1.000000  0.888889
# 3  1.00  0.692308  1.000000

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()
scaled_df = scalar1.fit_transform(df1)
scaled_df
# Out:
# array([[0.        , 0.61538462, 0.        ],
#        [0.25      , 0.        , 0.55555556],
#        [0.75      , 1.        , 0.88888889],
#        [1.        , 0.69230769, 1.        ]])

# %%
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df
# Out:
#     age    height    weight
# 0  0.00  0.615385  0.000000
# 1  0.25  0.000000  0.555556
# 2  0.75  1.000000  0.888889
# 3  1.00  0.692308  1.000000
